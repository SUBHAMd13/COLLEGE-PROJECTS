# %% [markdown]
# # HABERMAN SURVIVAL DATASET

# %% [markdown]
# Read the haberman survival dataset and print the number of rows and column.
# Here we import pandas, a data processing and CSV file I/O library.
# We also import seaborn, a Python graphing library.

# %%
    import pandas as pd
    import seaborn as sns
    import matplotlib.pyplot as plt
    
    haberman = pd.read_csv("/home/subham/Downloads/HABERMAN SURVIVAL DATASET/haberman.csv") #the haberman dataset is now in a Pandas DataFrame
    print (haberman.shape)
# Out:
# (306, 4)

# %% [markdown]
# Relevant Information: The dataset contains cases from a study that was conducted between 1958 and 1970 at the University of Chicago's Billings Hospital on the survival of patients who had undergone surgery for breast cancer.
#
# Attribute Information:
#
# Age of patient at time of operation (numerical)
# Patient's year of operation (year - 1900, numerical)
# Number of positive axillary nodes detected (numerical)
# Survival status (class attribute)
#
# 1 = the patient survived 5 years or longer
# 2 = the patient died within 5 year.

# %%
haberman.head()
# Out:
#    age  year  axillary  survived
# 0   30    64         1         1
# 1   30    62         3         1
# 2   30    65         0         1
# 3   31    59         2         1
# 4   31    65         4         1

# %% [markdown]
# In this phase you enhance the quality of the data and prepare it for use in subsequent steps.
# Data transformation ensures that the data is in a suitable format for use in your models.

# %%
haberman.describe()
# Out:
#               age        year    axillary    survived
# count  306.000000  306.000000  306.000000  306.000000
# mean    52.457516   62.852941    4.026144    1.264706
# std     10.803452    3.249405    7.189654    0.441899
# min     30.000000   58.000000    0.000000    1.000000
# 25%     44.000000   60.000000    0.000000    1.000000
# 50%     52.000000   63.000000    1.000000    1.000000
# 75%     60.750000   65.750000    4.000000    2.000000
# max     83.000000   69.000000   52.000000    2.000000

# %% [markdown]
# In the dataset age, year, axillary are features. Here axillary nodes means Lymph nodes which are small clumps of immune cells that act as filters for the lymphatic system. The lymphatic system runs throughout the body (like the circulatory (blood) system) and carries fluid and cells.
# If breast cancer spreads, the lymph  axillary nodes in the underarm (the axillary lymph nodes) are the first place it’s likely to go.

# %%
print (haberman.columns)
# Out:
# Index([u'age', u'year', u'axillary', u'survived'], dtype='object')

# %%
haberman["survived"].value_counts()
# Out:
# 1    225
# 2     81
# Name: survived, dtype: int64

# %%
haberman.plot()
plt.show()

# %%
haberman.hist()
plt.show()

# %% [markdown]
# Data exploration is concerned with building a deeper understanding of your data.
# You try to understand how variables interact with each other,
# the distribution of the data,and whether there are outliers.
# To achieve this you mainly use descriptive statistics, visual techniques, plots and simple modeling.

# %% [markdown]
# # SCATTERPLOT

# %% [markdown]
# Draw a scatterplot of axillary  with respect to age.
# We'll use seaborn's FacetGrid to color the scatterplot by survived or not  survived.

# %%
sns.FacetGrid(haberman, hue="survived", size=5).map(plt.scatter, "age", "axillary").add_legend()
plt.show()

# %% [markdown]
# Draw an another scatterplot of axillary  with respect to year.

# %%
sns.FacetGrid(haberman, hue="survived", size=5).map(plt.scatter, "year", "axillary").add_legend()
plt.show()

# %% [markdown]
# Most of the datapoints of the above plot have overlapped for integer value.
# Draw a scatterplot of age with respect to year.

# %%
sns.FacetGrid(haberman, hue="survived", size=5).map(plt.scatter, "year", "age").add_legend()
plt.show()

# %% [markdown]
# # PAIRPLOT

# %% [markdown]
# From above scatterplots we can't decide anything. Here also overlapping spread through out the space.
# Another useful seaborn plot is the pairplot, which shows the bivariate relation between each pair of features.
# So draw a pairplot on 3 features.

# %%
sns.pairplot(haberman, hue="survived",vars=("age","year","axillary"), size=3, diag_kind="kde")
plt.show()

# %%
sns.pairplot(haberman, hue="survived",vars=("age","year","axillary"), size=3, diag_kind="hist")
plt.show()

# %% [markdown]
# # PDF

# %% [markdown]
# Through above pairplot nothing can be determined.Draw the pdf of each features.
# A final seaborn plot useful for looking at univariate relations is the kdeplot,
# which creates and visualizes a kernel density estimate of the underlying feature.

# %%
sns.FacetGrid(haberman, hue="survived",size=6).map(sns.kdeplot,"axillary").add_legend()
plt.show()

# %%
sns.FacetGrid(haberman, hue="survived",size=6).map(sns.kdeplot,"year").add_legend()
plt.show()

# %%
sns.FacetGrid(haberman, hue="survived",size=6).map(sns.kdeplot,"age").add_legend()
plt.show()

# %% [markdown]
# In the pdf plots for all features are overlapped on each other.

# %% [markdown]
# # BOXPLOT

# %% [markdown]
# Now we will try boxplot to visualize each features.
# We can look at an individual feature in Seaborn through a boxplot.

# %%
sns.boxplot(x='survived',y='axillary', data=haberman)
plt.show()

# %%
sns.boxplot(x='survived',y='age', data=haberman)
plt.show()

# %%
sns.boxplot(x='survived',y='year', data=haberman)
plt.show()

# %% [markdown]
# One way we can extend this plot is adding a layer of individual points on top of
# it through Seaborn's striplot.
#
#  We'll use jitter=True so that all the points don't fall in single vertical lines
#  above the survived.
#
#  Saving the resulting axes as ax each time causes the resulting plot to be shown
#  on top of the previous axes

# %%
ax = sns.boxplot(x='survived',y='axillary', data=haberman)
plt.show()
ax = sns.stripplot(x='survived',y='axillary', data=haberman, jitter=True, edgecolor="gray")
plt.show()

# %%
ax = sns.boxplot(x='survived',y='age', data=haberman)
plt.show()
ax = sns.stripplot(x='survived',y='age', data=haberman, jitter=True, edgecolor="gray")
plt.show()

# %%
ax = sns.boxplot(x='survived',y='year', data=haberman)
plt.show()
ax = sns.stripplot(x='survived',y='year', data=haberman, jitter=True, edgecolor="gray")
plt.show()

# %% [markdown]
# We can make a boxplot with Pandas on each feature split out by survived feature.

# %%
haberman.boxplot(by="survived", figsize=(12, 6))
plt.show()

# %% [markdown]
# # VIOLINPLOT

# %% [markdown]
# A violin plot combines the benefits of the previous two plots and simplifies them.
# Denser regions of the data are fatter, and sparser thiner in a violin plot.

# %%
sns.violinplot(x='survived',y='axillary', data=haberman, size=6)
plt.show()

# %%
sns.violinplot(x='survived',y='age', data=haberman, size=6)
plt.show()

# %%
sns.violinplot(x='survived',y='year', data=haberman, size=6)
plt.show()

# %% [markdown]
# No such decision we can't take from box plot or violin plot.

# %% [markdown]
# # CDF

# %% [markdown]
# the cumulative distribution function (CDF) of a real-valued random variable X, or just distribution function of X, evaluated at x, is the probability that X will take a value less than or equal to x.
#
# CDF also used to test to see whether two empirical distributions are different or whether an empirical distribution is different from an ideal distribution.
#
# Plot CDF of each feature and also cummulate them.

# %%
ax = sns.kdeplot(haberman['axillary'], cumulative=True)

plt.show()

# %%
ax = sns.kdeplot(haberman['age'], cumulative=True)

plt.show()

# %%
ax = sns.kdeplot(haberman['year'], cumulative=True)

plt.show()

# %%
ax = sns.kdeplot(haberman['axillary'], cumulative=True)
ax = sns.kdeplot(haberman['age'], cumulative=True)
ax = sns.kdeplot(haberman['year'], cumulative=True)
plt.show()

# %% [markdown]
# # PARALLEL CO-ORDINATES PLOT

# %% [markdown]
# Another multivariate visualization technique pandas has is parallel_coordinates.
# Parallel coordinates plots each feature on a separate column & then draws lines connecting the features for each data sample.

# %%
from pandas.plotting import parallel_coordinates
parallel_coordinates(haberman, "survived")
plt.show()

# %% [markdown]
# # ANDREWS CURVES

# %% [markdown]
# One cool more sophisticated technique pandas has available is called Andrews Curves.
# Andrews Curves involve using attributes of samples as coefficients for Fourier series and then plotting these.

# %%
from pandas.plotting import andrews_curves
andrews_curves(haberman, "survived")
plt.show()

# %% [markdown]
# # RADVIZ PLOT

# %% [markdown]
# Another multivariate visualization technique pandas has is radviz.
# Which puts each feature as a point on a 2D plane, and then simulates having each sample attached to those points through a spring weighted by the relative value for that feature.

# %%
from pandas.plotting import radviz
radviz(haberman, "survived")
plt.show()

# %% [markdown]
# Here we try to visualize the HABERMAN dataset which contains noises using verious univariate, bivariate, multivariate plot. It is a problem to seperate survived(1) or not survived(2) using given features. I think more features are required to visualize and seperate those two classes.
